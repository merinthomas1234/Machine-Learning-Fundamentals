# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\MERIN\1. hr_analytics.xls")

df
# Out:
#      Age  Gender Department  MonthlyIncome  TotalWorkingYears  YearsAtCompany  \
# 0     50  Female         HR           4753                 14               8
# 1     36    Male        R&D          13123                  3               7
# 2     29    Male         HR          19376                 16              15
# 3     42    Male         HR           9588                 19              14
# 4     40    Male        R&D           9304                 18               8
# ..   ...     ...        ...            ...                ...             ...
# 995   34  Female      Sales           7986                  2               5
# 996   51  Female      Sales           4481                 26              12
# 997   44    Male         HR           6731                 27               6
# 998   40  Female      Sales          19835                 27               9
# 999   53  Female         HR          13758                 15               1
#
# ...

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 1000
# Number of columns: 10

# %%
print(df.dtypes)
# Out:
# Age                   int64
# Gender               object
# Department           object
# MonthlyIncome         int64
# TotalWorkingYears     int64
# YearsAtCompany        int64
# JobSatisfaction       int64
# WorkLifeBalance       int64
# OverTime             object
# Attrition            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Department           0
# MonthlyIncome        0
# TotalWorkingYears    0
# YearsAtCompany       0
# JobSatisfaction      0
# WorkLifeBalance      0
# OverTime             0
# Attrition            0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Age                  0
# Gender               0
# Department           0
# MonthlyIncome        0
# TotalWorkingYears    0
# YearsAtCompany       0
# JobSatisfaction      0
# WorkLifeBalance      0
# OverTime             0
# Attrition            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                1000 non-null   int64
#  1   Gender             1000 non-null   object
#  2   Department         1000 non-null   object
#  3   MonthlyIncome      1000 non-null   int64
#  4   TotalWorkingYears  1000 non-null   int64
#  5   YearsAtCompany     1000 non-null   int64
#  6   JobSatisfaction    1000 non-null   int64
#  7   WorkLifeBalance    1000 non-null   int64
#  8   OverTime           1000 non-null   object
#  9   Attrition          1000 non-null   object
# dtypes: int64(6), object(4)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#                Age  MonthlyIncome  TotalWorkingYears  YearsAtCompany  \
# count  1000.000000    1000.000000        1000.000000     1000.000000
# mean     40.947000   11496.427000          17.518000       10.273000
# std      11.160858    4897.403307           9.585696        5.494967
# min      22.000000    3024.000000           1.000000        1.000000
# 25%      31.000000    7240.250000          10.000000        6.000000
# 50%      42.000000   11709.000000          17.000000       11.000000
# 75%      50.000000   15657.500000          26.000000       15.000000
# max      59.000000   19998.000000          34.000000       19.000000
#
#        JobSatisfaction  WorkLifeBalance
# count      1000.000000      1000.000000
# mean          2.475000         2.463000
# std           1.124562         1.101746
# min           1.000000         1.000000
# 25%           1.000000         1.000000
# 50%           2.000000         2.000000
# 75%           4.000000         3.000000
# ...

# %%
total_employees = len(df)
print(f"There are {total_employees} employees in the dataset.")
# Out:
# There are 1000 employees in the dataset.

# %%
num_departments = df['Department'].nunique()
print(f"There are {num_departments} departments in the dataset.")
# Out:
# There are 3 departments in the dataset.

# %%
all_departments = df['Department'].unique()
print(all_departments)
# Out:
# ['HR' 'R&D' 'Sales']

# %%
average_age = df['Age'].mean()
print(f"The average employee age is: {average_age:.1f} years old")
# Out:
# The average employee age is: 40.9 years old

# %%
min_age = df['Age'].min()
max_age = df['Age'].max()
print(f"Youngest employee age: {min_age} years old")
print(f"Oldest employee age: {max_age} years old")
# Out:
# Youngest employee age: 22 years old
# Oldest employee age: 59 years old

# %%
gender_counts = df['Gender'].value_counts()
print(gender_counts)
# Out:
# Gender
# Male      504
# Female    496
# Name: count, dtype: int64

# %%
department_counts = df['Department'].value_counts()
print(department_counts)
# Out:
# Department
# HR       352
# Sales    343
# R&D      305
# Name: count, dtype: int64

# %%
(df["TotalWorkingYears"]>10).sum()
# Out:
# np.int64(720)

# %%
df.groupby("Department")["MonthlyIncome"].mean()
# Out:
# Department
# HR       11604.042614
# R&D      11461.272131
# Sales    11417.247813
# Name: MonthlyIncome, dtype: float64

# %%
df[df["Attrition"] == "Yes"].groupby("Department").size()
# Out:
# Department
# HR       70
# R&D      74
# Sales    59
# dtype: int64
